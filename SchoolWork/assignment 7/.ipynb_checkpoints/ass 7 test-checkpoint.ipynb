# %% [markdown]
# # Kelachi Charles-Beke
# ## 201651312
# ## Comp 4304 Assignment 7
# ##  11/16/2021

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick

from ipywidgets import interact, interact_manual 
import ipywidgets as widgets

# %% [markdown]
# ### Question 1

# %%
df = pd.read_csv('Documents/olympic_athletes.csv')
df = df[(df.Year == 2016)]
df_medal = df[(df.Medal == 'Gold') & (df.Sport.isin(['Swimming', 'Wrestling', 'Fencing', 'Athletics', 'Shooting', 'Cycling', 'Rowing', 'Gymnastics']))]
df = df_medal[['ID', 'Height', 'Sport']].drop_duplicates()
df
fig, ax = plt.subplots(figsize = (9,6))
ax = sns.violinplot(x ='Sport', y = 'Height', data = df, inner = 'quartiles', scale = 'width')
ax = sns.swarmplot(x ='Sport', y = 'Height', data = df, color ='black')
ax.set_yticks([140, 150, 160, 170, 180, 190, 200, 210, 220])
ax.set_yticklabels(['140', '150', '160', '170', '180', '190', '200', '210', '220'])
plt.title('Gold-medal Winning Heights at the 2016 Olympics')
# Out:
# Text(0.5, 1.0, 'Gold-medal Winning Heights at the 2016 Olympics')

# %% [markdown]
# ### Question 2

# %%
df = pd.read_csv('Documents/olympic_athletes.csv')

df = df[(df.Year >= 2000) & (df.Year <= 2016)]

df_medal = df[(df.Medal == 'Gold') & (df.Sport.isin(['Swimming', 'Wrestling', 'Fencing', 'Athletics', 'Shooting', 'Cycling', 'Rowing', 'Gymnastics']))]
df_combine = df_medal[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_swim = df[(df.Medal == 'Gold') & (df.Sport == 'Swimming')]
df_swim = df_swim[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_wres = df[(df.Medal == 'Gold') & (df.Sport == 'Wrestling')]
df_wres = df_wres[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_fen = df[(df.Medal == 'Gold') & (df.Sport == 'Fencing')]
df_fen = df_fen[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_athl = df[(df.Medal == 'Gold') & (df.Sport == 'Athletics')]
df_athl = df_athl[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_shoot = df[(df.Medal == 'Gold') & (df.Sport == 'Shooting')]
df_shoot = df_shoot[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_cycl = df[(df.Medal == 'Gold') & (df.Sport == 'Cycling')]
df_cycl = df_cycl[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_rowg = df[(df.Medal == 'Gold') & (df.Sport == 'Rowing')]
df_rowg = df_rowg[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()

df_gymn = df[(df.Medal == 'Gold') & (df.Sport == 'Gymnastics')]
df_gymn = df_gymn[['ID', 'Height', 'Weight', 'Sport', 'Sex', 'Year']].drop_duplicates()


@interact(x = widgets.Dropdown(options = ['Combined', 'Swimming', 'Wrestling', 'Fencing', 'Athletics', 'Shooting', 'Cycling', 'Rowing', 'Gymnastics'], 
                               description = 'Sport'), kde = widgets.Checkbox(options = 'Kde'), display_data = widgets.Checkbox(options = 'display_data'))

def f(x, kde, display_data):
    

          
    if(x == 'Combined'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_combine, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_combine, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_combine, hue ='Sex')
            
            
    if(x == 'Swimming'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_swim, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_swim, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_swim, hue ='Sex')
            
    if(x == 'Wrestling'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_wres, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_wres, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_wres, hue ='Sex')
    
    if(x == 'Fencing'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_fen, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_fen, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_fen, hue ='Sex')
            
    if(x == 'Athletics'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_athl, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_athl, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_athl, hue ='Sex')
            
    if(x == 'Shooting'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_shoot, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_shoot, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_shoot, hue ='Sex')
            
    if(x == 'Cycling'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_cycl, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_cycl, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_cycl, hue ='Sex')
            
    if(x == 'Rowing'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_rowg, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_rowg, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_rowg, hue ='Sex')
    
    if(x == 'Gymnastics'):
        fig, ax = plt.subplots(figsize =(7,5))
        ax = sns.histplot(x = 'Weight', y = 'Height', data = df_gymn, binwidth=(5,5), binrange = ((20,140),(130,220)), stat = 'count', cmap = 'Blues')
        if(kde):
            ax = sns.kdeplot(x = 'Weight', y = 'Height', data = df_gymn, fill = True, cmap = 'Blues')
        if(display_data):
            ax = sns.scatterplot(y = 'Height', x = 'Weight', data = df_gymn, hue ='Sex')
            
          
    ax.set_xlim((20, 140))
    ax.set_ylim((130, 220))
    plt.title('Height & Weight Distribution for Olympic Gold Medal winning\n'
              'Athletes from 2000 to 2016')
# Out:
# interactive(children=(Dropdown(description='Sport', options=('Combined', 'Swimming', 'Wrestling', 'Fencing', '…

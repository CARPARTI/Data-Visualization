# %% [markdown]
# # Assignment 5
# ## Oluwanifemi Ajayi - 201652476

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("used_cars.csv")
df2 = pd.read_csv("iris.csv")

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Question 1

# %%
sns.scatterplot(data = df2, x = "petal_length", y = "petal_width", hue = "species" )
plt.title("Iris Petal")
# Out:
# Text(0.5, 1.0, 'Iris Petal')

# %% [markdown]
# ## Question 2

# %%
df2['area']=df2['petal_length']*df2['petal_width']

# %%
fig, ax = plt.subplots(figsize=(9,5))
sns.barplot(y = df2["species"], x = df2["area"], order = ["setosa", "versicolor","virginica"], data =df2["area"], ci = 95)

plt.title("Average Petal Area for Iris petal")
ax.set_xlim((0,12))
ax.set_xlabel("petal_area")
plt.show()

# %% [markdown]
# ## Questions 3

# %%
df1
# Out:
#       model  year  price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2        A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 4        A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# ...     ...   ...    ...          ...      ...      ...    ...   ...
# 99182   Eos  2012   5990       Manual    74000   Diesel  125.0  58.9
# 99183   Fox  2008   1799       Manual    88102   Petrol  145.0  46.3
# 99184   Fox  2009   1590       Manual    70000   Petrol  200.0  42.0
# 99185   Fox  2006   1250       Manual    82704   Petrol  150.0  46.3
# 99186   Fox  2007   2295       Manual    74000   Petrol  145.0  46.3
#
#        engineSize       brand
# 0             1.4        Audi
# 1             2.0        Audi
# 2             1.4        Audi
# ...

# %%
df1 = df1.sort_values(by="year", ascending =False)
df1 = df1[(df1.year >= 2005) & (df1.year <= 2019)]

# %%
df1.year.unique()
# Out:
# array([2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009,
#        2008, 2007, 2006, 2005], dtype=int64)

# %%
data1 = [df1.price[df1.year == year] for year in df1.year.unique()]

# %%
fig, ax = plt.subplots(figsize=(20,9))
sns.violinplot(x = "price", y = "year", orient = "h", scale='width', inner='quartiles', data = df1, ax=ax)
ax.set_xlim((0,60000))
ax.set_xticks([0, 10000,20000,30000,40000,50000,60000])
ax.set_xticklabels(["0","10k","20k","30k","40k","50k","60k"]) 
plt.title("Distribution of Used Car Prices")
plt.show()

# %% [markdown]
# ## Question 4

# %%
df1 = pd.read_csv("used_cars.csv")

# %%
df1.head()
# Out:
#   model  year  price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150.0  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20.0  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30.0  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145.0  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145.0  49.6         1.0
#
#   brand
# 0  Audi
# 1  Audi
# 2  Audi
# 3  Audi
# 4  Audi

# %%
df1 = df1[(df1.year >= 2000) & (df1.year <= 2019)]
dfA = df1[ (df1.transmission == "Manual") | (df1.transmission == "Automatic") ]

# %%
fig, axes = plt.subplots(figsize=(20,9))

##axes=fig.add_axes([0,0,2,2]) 
##axes1=fig.add_axes([0,1,2,2])

sns.lineplot(x = "year", y = "price", data =dfA, hue = "transmission", palette=["orange","blue"])


##sns.barplot(x = dfA["price"], y = dfA["transmission"])


ax.set_xlim((2000,2018))
ax.set_ylim((0,35000))
ax.set_xticks([2000, 2003,2006,2009,2012,2015,2018])
ax.set_xticklabels(["2000","2003","2006","2009","2012","2015","2018"]) 
plt.title("Average used car prices")
plt.show()
##sns.lineplot(x = "year", y = "price", data =dfM, hue = "transmission", color = "orange")

# %%
sns.barplot(x = dfA["price"], y = dfA["transmission"])
# Out:
# <AxesSubplot:xlabel='price', ylabel='transmission'>

# %% [markdown]
# ### Attribution: https://stackabuse.com/seaborn-bar-plot-tutorial-and-examples/

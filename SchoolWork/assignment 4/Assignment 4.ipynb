# %% [markdown]
# # Assignment 4
# ## Oluwanifemi Ajayi - 201652476

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib_venn as venn
import squarify

# %%
df = pd.read_csv("game_consoles_untidy.csv")
df1 =pd.read_csv("used_cars.csv")
ddf = pd.read_csv("game_consoles.csv")

# %%
df
# Out:
#                       Console    variable      value
# 0               PlayStation 2  Units_sold  155000000
# 1          Nintendo DS family  Units_sold  154002000
# 2   Game Boy & Game Boy Color  Units_sold  118690000
# 3               PlayStation 4  Units_sold  116400000
# 4                 PlayStation  Units_sold  102490000
# ..                        ...         ...        ...
# 95              PlayStation 5     Release       2020
# 96            Xbox Series X/S     Release       2020
# 97  Super NES Classic Edition     Release       2017
# 98              Color TV-Game     Release       1977
# 99        NES Classic Edition     Release       2016
#
# [100 rows x 3 columns]

# %% [markdown]
# ## Qustion 1

# %%
df.pivot(index=['Console'], columns='variable', values='value').reset_index()
# Out:
# variable                              Console    Company Release       Type  \
# 0                               Color TV-Game   Nintendo    1977  Dedicated
# 1                   Game Boy & Game Boy Color   Nintendo    1989   Handheld
# 2                     Game Boy Advance family   Nintendo    2001   Handheld
# 3                                    GameCube   Nintendo    2001       Home
# 4                         NES Classic Edition   Nintendo    2016  Dedicated
# 5                         Nintendo 3DS family   Nintendo    2011   Handheld
# 6                                 Nintendo 64   Nintendo    1996       Home
# 7                          Nintendo DS family   Nintendo    2004   Handheld
# 8               Nintendo Entertainment System   Nintendo    1983       Home
# 9                             Nintendo Switch   Nintendo    2017     Hybrid
# 10                                PlayStation       Sony    1994       Home
# ...

# %%
df1
# Out:
#       model  year  price transmission  mileage fuelType    tax   mpg  \
# 0        A1  2017  12500       Manual    15735   Petrol  150.0  55.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20.0  64.2
# 2        A1  2016  11000       Manual    29946   Petrol   30.0  55.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145.0  67.3
# 4        A3  2019  17300       Manual     1998   Petrol  145.0  49.6
# ...     ...   ...    ...          ...      ...      ...    ...   ...
# 99182   Eos  2012   5990       Manual    74000   Diesel  125.0  58.9
# 99183   Fox  2008   1799       Manual    88102   Petrol  145.0  46.3
# 99184   Fox  2009   1590       Manual    70000   Petrol  200.0  42.0
# 99185   Fox  2006   1250       Manual    82704   Petrol  150.0  46.3
# 99186   Fox  2007   2295       Manual    74000   Petrol  145.0  46.3
#
#        engineSize       brand
# 0             1.4        Audi
# 1             2.0        Audi
# 2             1.4        Audi
# ...

# %% [markdown]
# ## Question 2

# %%
df2 = df1.groupby(["year","brand"]).sum().reset_index()

# %%
df2.sort_values("price" , ascending=False).drop_duplicates(subset="year" , keep ="first")
# Out:
#      year     brand      price    mileage       tax       mpg  engineSize
# 181  2019  Mercedes  142463465   31820153  667035.0  232271.8      9183.1
# 161  2017      Ford   58488292  110223529  545890.0  290013.5      6751.7
# 170  2018      Ford   52815789   63051085  585175.0  235666.9      4928.1
# 154  2016  Mercedes   38055857   67480117  175340.0  121760.0      4184.6
# 187  2020       BMW   25931840    1096086  106800.0   33646.2      1611.9
# 145  2015  Mercedes   16581194   42711901   95625.0   58739.1      2165.0
# 136  2014  Mercedes    6895082   23571718   48860.0   28635.4      1022.5
# 125  2013      Ford    4082700   29254983   38735.0   35187.4       845.5
# 115  2012       BMW    1134509    8421102   15660.0    6450.3       260.4
# 109  2011  Mercedes     479746    2659159    9360.0    1679.9        93.1
# 89   2009      Ford     338495    6820286   14840.0    4386.9       143.7
# 100  2010  Mercedes     315722    3175390   12075.0    1509.7        95.3
# ...

# %%
fig, ax = plt.subplots()

ax.violinplot(df2["price"], showmedians=True, vert=False)
##xticklabels =[df2["price"]]
yticklabels =[df2["year"]]
##ax.set_xticks(df2["price"])
ax.set_yticks(df2["year"])
##ax.set_xticklabels(xticklabels)
##ax.set_yticklabels(yticklabels)
plt.show()

# %%
fig, ax = plt.subplots()
ax.violinplot(df2["year"], showmedians=True, vert=False)
xticklabels = df2["price"]
plt.title("Distribution of used cars")
plt.xlabel("Price")
# Out:
# Text(0.5, 0, 'Price')

# %% [markdown]
# ## Question 3

# %%
ddf
# Out:
#                  Console       Type    Company  Release  Units_sold
# 0          PlayStation 2       Home       Sony     2000   155000000
# 1            Nintendo DS   Handheld   Nintendo     2004   154002000
# 2               Game Boy   Handheld   Nintendo     1989   118690000
# 3          PlayStation 4       Home       Sony     2013   116400000
# 4            PlayStation       Home       Sony     1994   102490000
# 5                    Wii       Home   Nintendo     2006   101630000
# 6        Nintendo Switch     Hybrid   Nintendo     2017    89040000
# 7          PlayStation 3       Home       Sony     2006    87400000
# 8               Xbox 360       Home  Microsoft     2005    84000000
# 9       Game Boy Advance   Handheld   Nintendo     2001    81510000
# 10  PlayStation Portable   Handheld       Sony     2004    82000000
# 11          Nintendo 3DS   Handheld   Nintendo     2011    75940000
# 12                   NES       Home   Nintendo     1983    61910000
# ...

# %%
ddf[ddf["Company"].str.contains("Sony")]
# Out:
#                  Console      Type Company  Release  Units_sold
# 0          PlayStation 2      Home    Sony     2000   155000000
# 3          PlayStation 4      Home    Sony     2013   116400000
# 4            PlayStation      Home    Sony     1994   102490000
# 7          PlayStation 3      Home    Sony     2006    87400000
# 10  PlayStation Portable  Handheld    Sony     2004    82000000
# 19      PlayStation Vita  Handheld    Sony     2011    15000000
# 20         PlayStation 5      Home    Sony     2020    10000000

# %%
sony =ddf[ddf["Company"].str.contains("Sony")]
microsoft = ddf[ddf["Company"].str.contains("Microsoft")]
nintendo =ddf[ddf["Company"].str.contains("Nintendo")]

# %%
dataset=[sony,microsoft,nintendo]

# %%
sony
# Out:
#                  Console      Type Company  Release  Units_sold
# 0          PlayStation 2      Home    Sony     2000   155000000
# 3          PlayStation 4      Home    Sony     2013   116400000
# 4            PlayStation      Home    Sony     1994   102490000
# 7          PlayStation 3      Home    Sony     2006    87400000
# 10  PlayStation Portable  Handheld    Sony     2004    82000000
# 19      PlayStation Vita  Handheld    Sony     2011    15000000
# 20         PlayStation 5      Home    Sony     2020    10000000

# %%
dataset
# Out:
# [                 Console      Type Company  Release  Units_sold
#  0          PlayStation 2      Home    Sony     2000   155000000
#  3          PlayStation 4      Home    Sony     2013   116400000
#  4            PlayStation      Home    Sony     1994   102490000
#  7          PlayStation 3      Home    Sony     2006    87400000
#  10  PlayStation Portable  Handheld    Sony     2004    82000000
#  19      PlayStation Vita  Handheld    Sony     2011    15000000
#  20         PlayStation 5      Home    Sony     2020    10000000,
#              Console  Type    Company  Release  Units_sold
#  8          Xbox 360  Home  Microsoft     2005    84000000
#  13         Xbox One  Home  Microsoft     2013    51000000
#  16             Xbox  Home  Microsoft     2001    24000000
#  21  Xbox Series X/S  Home  Microsoft     2020     6500000,
#               Console       Type   Company  Release  Units_sold
#  1        Nintendo DS   Handheld  Nintendo     2004   154002000
# ...

# %%
fig, ax = plt.subplots(nrows=1, ncols=3,figsize=(25,20))

a=squarify.plot(sony.Units_sold, label=sony.Console, color ="blue" , alpha=0.5,pad=True, ax=ax[0])
b=squarify.plot(microsoft.Units_sold, label=microsoft.Console, color ="red" , alpha=0.5,pad=True, ax=ax[1])
c=squarify.plot(nintendo.Units_sold, label=nintendo.Console,color ="yellow" , alpha=0.5,pad=True, ax=ax[2])

plt.title("Consoles Sales")

ax[0].axis('off')
ax[1].axis('off')
ax[2].axis('off')
# Out:
# (0.0, 100.0, 0.0, 100.0)

# %%
test = [a,b,c]

# %%
plt(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4236/2801175395.py in <module>
# ----> 1 plt(test)
#
# TypeError: 'module' object is not callable

# %% [markdown]
# # Attrition: https://towardsdatascience.com/treemap-basics-with-python-777e5ed173d0
